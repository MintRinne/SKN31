# %%
#실행 단축키 : shift + enter (실행하고 다음 셀로 이동)
#             control + enter (실행만 함)
# cell 위에 빈 cell 만들기 : a
# cell 아래 빈 cell 만들기 : b
# cell 삭제 : dd (x : 잘라내기)
#---모드 변경 단축키
# cell을 파이썬 모드로 변경 : y
# cell을 markdown 모드로 변경 : m
1+1
# Out:
# 2

# %%
num1 = 10

# %%
num2 = 20

# %%
num3 = num1 + num2

# %%
print(num3)
# Out:
# 30

# %% [markdown]
# 이태리체 *기울림*, _기울림체_
# 볼드체 **진하게**, __진하게__
# 이태리+볼드 : ***둘합친것***,__*둘다*__
#
# ###링크
# -[내용](url)
# [네이버](https://naver.com)
# -![이미지](이미지 경로 - url, 파일 경로)
#
# ## !는 이미지, 없으면 링크
# ![이미지입니다](images\ch01_01.png)
